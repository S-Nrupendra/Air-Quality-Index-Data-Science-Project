# %%
import pandas as pd

# %%
station_day = pd.read_csv("station_day.csv\station_day.csv")
city_hour = pd.read_csv("station_day.csv\city_hour.csv")

print("Station day shape:", station_day.shape)
print("City hour shape:", city_hour.shape)

# # Drop non-common columns
# drop_cols_station = ['StationId', 'Date']
# drop_cols_city = ['City', 'Datetime']

# station_day = station_day.drop(columns=drop_cols_station, errors='ignore')
# city_hour = city_hour.drop(columns=drop_cols_city, errors='ignore')

# # Get the common columns
# common_cols = list(set(station_day.columns) & set(city_hour.columns))
# print("Common columns:", common_cols)

# # Keep only common columns in both
# station_day = station_day[common_cols]
# city_hour = city_hour[common_cols]

# # Merge (concatenate) them row-wise
# merged_data = pd.concat([station_day, city_hour], ignore_index=True)

# print("Merged dataset shape:", merged_data.shape)
# Out:
# Station day shape: (108035, 16)
# City hour shape: (707875, 16)

# %%
(city_hour.isnull().sum() * 100 / len(city_hour)).sort_values(ascending=False)
# Out:
# Xylene        64.393996
# PM10          41.919407
# NH3           38.501430
# Toluene       31.164683
# Benzene       23.117923
# PM2.5         20.496274
# SO2           18.417517
# O3            18.252940
# AQI_Bucket    18.234858
# AQI           18.234858
# NOx           17.407593
# NO2           16.545577
# NO            16.476355
# CO            12.222073
# Datetime       0.000000
# City           0.000000
# dtype: float64

# %%
(station_day.isnull().sum() * 100 / len(station_day)).sort_values(ascending=False)
# Out:
# Xylene        78.805017
# NH3           44.527237
# PM10          39.529782
# Toluene       35.823576
# Benzene       29.115564
# O3            23.666404
# SO2           23.329477
# PM2.5         20.016661
# AQI_Bucket    19.447401
# AQI           19.447401
# NO            15.833758
# NO2           15.316333
# NOx           14.347202
# CO            12.031286
# Date           0.000000
# StationId      0.000000
# dtype: float64
