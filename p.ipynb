# %%
import pandas as pd

# %%
data_with_xylene = pd.read_csv('cleaned_with_xylene.csv')
data_without_xylene = pd.read_csv("cleaned_without_xylene.csv")

# %%
data_with_xylene['AQI'].describe()
# Out:
# count    108035.000000
# mean        168.055713
# std         108.293408
# min           8.000000
# 25%          96.000000
# 50%         132.000000
# 75%         211.000000
# max         500.000000
# Name: AQI, dtype: float64

# %%
data_without_xylene['AQI'].describe()
# Out:
# count    108035.000000
# mean        168.055713
# std         108.293408
# min           8.000000
# 25%          96.000000
# 50%         132.000000
# 75%         211.000000
# max         500.000000
# Name: AQI, dtype: float64

# %%
station_day = pd.read_csv('station_day.csv\station_day.csv')
stations = pd.read_csv('station_day.csv\stations.csv')

print("Station day shape:", station_day.shape)
print("Stations shape:", stations.shape)
# Out:
# Station day shape: (108035, 16)
# Stations shape: (230, 5)

# %%
print("Common columns:", set(station_day.columns).intersection(stations.columns))

if 'station_id' in station_day.columns and 'station_id' in stations.columns:
    data = station_day.merge(stations, on='station_id', how='left')
else:
    data = station_day.copy()

print("Merged shape:", data.shape)

drop_cols = ['StationId', 'StationName', 'state', 'city', 'location', 'Date', 'date']
drop_cols = [c for c in drop_cols if c in data.columns]
data = data.drop(columns=drop_cols, errors='ignore')

print("After dropping irrelevant columns:", data.shape)
# Out:
# Common columns: {'StationId'}
# Merged shape: (108035, 16)
# After dropping irrelevant columns: (108035, 14)

# %%
cat_cols = data.select_dtypes(include=['object']).columns
num_cat_cols = data.select_dtypes(include=['number', 'bool']).columns

print("Categorical columns:", cat_cols.tolist())
print("Numerical/Boolean columns:", num_cat_cols.tolist())
# Out:
# Categorical columns: ['AQI_Bucket']
# Numerical/Boolean columns: ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']

# %%
data.isnull().sum()
# Out:
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       3 import numpy as np
#       5 # Load your models
# ----> 6 model_without = pickle.load(open("best_model_Without_Xylene.pkl", "rb"))
#       7 model_with = pickle.load(open("best_model_With_Xylene.pkl", "rb"))
#       9 # Test samples
#
# ModuleNotFoundError: No module named 'xgboost'
